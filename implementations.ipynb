# %% [markdown]
# <a href="https://colab.research.google.com/github/ANMOL0me/Python_Bootcamp/blob/main/implementations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # New Section

# %%
pip install streamlit
streamlit version

# %%
x1=2
x1+=4
print(x1)
x1*=x1
print(x1)
x1*=x1
print(x1)
x1*=x1
print(x1)

# %%
length = float(input("length"))
breadth = float(input("breadth"))
x = length * breadth * 0.5
print(x)

# %%
apple = 20
mango = 30
banana = 20
x = float(input("apple juice quantity:-\n"))
y = float(input("mango juice quantity1:-\n"))
z = float(input("banana juice quantity:-\n"))
a = (apple * x) + (mango * y) + (banana * z)
print("Amount:-",(a))
w=a
day = str(input("For weekend discount input day\t"))
day=="saturday"or day=="sunday"
day==True
w*=0.20
print("toatal amount",(a-w))

# %%
#project using format
apple = 20
mango = 30
banana = 20
x = float(input("apple juice quantity:-\n"))
y = float(input("mango juice quantity1:-\n"))
z = float(input("banana juice quantity:-\n"))
a = (apple * x) + (mango * y) + (banana * z)
#print("Amount:-",(a))
w=a
e=apple*x
r=mango*y
t=banana*z
day = str(input("For weekend discount input day\t"))
day=="saturday"or day=="sunday"
day==True
w*=0.2

#print("toatal amount",(a-w))
print("BILL\t\tquantity\tfixed price\tTotal\napple juice\t{}\t\t3{}\t\t{}".format(x,apple,e))
print("mango juice\t{}\t\t{}\t\t{}".format(y,mango,r))
print("banana juice\t{}\t\t{}\t\t{}".format(z,banana,t))
print("Total amount={}\t\tDisounted amount={}".format(a,a-w))

# %%
#use of format
x=10
y=3
z="akansha"
#print("hello,{2} x={0} y={1}".format(x,y,z))
print("hello,{} x={} y={}".format(y,x,z))
print("hi,{} {} {} {} {} ".format(x,y,z,x,y))

# %%
#gretaer than less than
x=int(input("x="))
if x>5:
    print("x is greater than 5")
if x<5:
  print("x is less than 5")
if x==5:
  print("x is 5")

# %%
#even odd
num = float(input("enter number"))
if num%2==0:
    print("even")
else:
    print("odd")

# %%
#calculator
num1 = float(input("num1\t="))
num2 = float(input("num2\t="))
operator = input("+\t-\t/\t*\t")
if operator=='+':
    print("sum=",(num1+num2))
if operator== '-':
    print("sub=",(num1-num2))
if operator=='/':
    print("div=",(num1/num2))
if  operator=='*':
    print("mul",(num1*num2))

# %%
    binary_number = 0b1100
    print(binary_number)

# %%
    decimal_number = 11
    binary_representation = bin(decimal_number)
    print(binary_representation)

# %%
month = int(input("enter your birth month"))
x= month*5
y=x+7
z=y*6
date = int(input("enter your birth date"))
c=z+date
w=c*25
t=w+1250
year = int(input("last two digit of your birth year"))
e=t+year

# %%
month = int(input("Birth Month\t\t:-\t"))
if num>=1 and num<=9 :
num = int(input("Chose no. from 1-9\t:-\t"))
w = num**2
w += 5
w *= 50
w += month
print(w)

# %%
a='math'
b='chem'
c='phy'
d='bio'
e='MPW'
f='civil'
print("\t\t1\t2\t3\t\t\t4\t5\t6\n\nMonday\t\t{}\t{}\t{}\t\t\t{}\t{}\t{}".format(a,b,c,d,e,f))
print("\n\nTuesday\t\t{}\t{}\t{}\t\tL\t{}\t{}\t{}".format(b,a,d,e,f,c))
print("\n\nWednesday\t{}\t{}\t{}\t\tU\t{}\t{}\t{}".format(c,d,f,e,a,b))
print("\n\nThursday\t{}\t{}\t{}\t\tN\t{}\t{}\t{}".format(f,e,d,a,c,b))
print("\n\nFriday\t\t{}\t{}\t{}\t\tC\t{}\t{}\t{}".format(d,e,f,a,b,c))
print("\n\nSaturday\t{}\t{}\t{}\t\tH\t{}\t{}\t{}".format(c,e,f,d,a,b))

# %%
#KBC
q1="what is my name?"
option1_a="anmol"
option1_b="dhruv"
option1_c="akshita"
option1_d="hardik"

q2="what is your name?"
option2_a="anmol"
option2_b="anmol"
option2_c="anmol"
option2_d="nonee"

print("\tQ1:-{}\n\tA:-{}\tB:-{}\n\n\tC:-{}\tD:-{}\n".format(q1,option1_a,option1_b,option1_c,option1_d))
ans = input("a,b,c,d:-")
if ans == "a":
    print("correct\n")
    print("\tQ2:-{}\n\tA:-{}\tB:-{}\n\n\tC:-{}\tD:-{}\n".format(q2,option2_a,option2_b,option2_c,option2_d))
    ans2 = input("a,b,c,d:-")
    if ans2 == "d":
        print("correct")
        print("yYOU WIN")
    else:
        print("wrong")
        print("game over")
else:
    print("wrong")
    print("game over")

# %%
code=int(input("WHAT IS YOUR CODE\n"))
if code%3==0 and code%5==0:
  print("YOU CAN GOOO")
elif code%3==0 or code%5==0:
  print("YOU ARE CLOSEE")
else :
  print("ACCESS DENIED")

# %%
x=1
while x<=5:
 print(x)
 x+=1

# %%
x=input("Enter a string")
count=0
for i in x:
  if i=='a':
    count+=1
print('Count=',count)

# %%
#BILLING COUNTER
print("\t\t\tMENU")
print("JUICE's\nAPPLE:-30\tMANGO:-40\tBANANA:-50")
print("\t#Type none if no order")
order1=str(input("ORDER_1:-"))
if order1=="none":
  print("NO ORDER")
  price1=0
  ordquan1=0
  print("price:-0")
elif order1=="apple":
  price1=30
  print("price:-{}".format(price1))
  ordquan1=int(input("Quantity:-"))

elif order1=="mango":
  price1=40
  print("price:-{}".format(price1))
  ordquan1=int(input("Quantity:-"))

elif order1=="banana":
  price1=50
  print("price:-{}".format(price1))
  ordquan1=int(input("Quantity:-"))

else:
  print("dont use your brain")
  price1=0
  ordquan1=0

price1
ordquan1
total1=ordquan1*price1
order2=str(input("ORDER_2:-"))

if order2=="none":
  print("NO ORDER")
  price2=0
  ordquan2=0
  print("price:-0")

elif order2=="apple":
  price2=30
  print("price:-{}".format(price2))
  ordquan2=int(input("Quantity:-"))

elif order2=="mango":
  price2=40
  print("price:-{}".format(price2))
  ordquan2=int(input("Quantity:-"))

elif order2=="banana":
  price2=50
  print("price:-{}".format(price2))
  ordquan2=int(input("Quantity:-"))

else:
  print("dont use your brain")
  price2=0
  ordquan2=0
  #total

total2=ordquan2*price2

alltot=total1+total2
print("\t\t\tBILLING")
print("Item\t\tQnt\t\tPrice\t\tTotal")
print("{}\t\t{}\t\t{}\t\t{}".format(order1,ordquan1,price1,total1))
print("{}\t\t{}\t\t{}\t\t{}".format(order2,ordquan2,price2,total2))
print("Total\t\t\t\t\t{}".format(alltot))
if alltot >=200:
  print("20% off on order of above 200")
  totaldis=total1*0.2+total2*0.2
  print("Total\t\t\t\t\t{}/-".format(alltot-totaldis))
else:
  print("No discount")
  print("Total\t\t\t\t\t{}/-".format(alltot))

# %%
year=int(input("Enter the year:"))
if year%4==0:
    print(year,"is a leap year")
else :
  print(year,"not a leap year")

# %%
q=int(input("from year:-"))
r=int(input("To year:-"))
x=i
count=0
if q<r:
  for i in range(q,r):
    if i%4==0:
      print("\t\t\t\t\t{}:-is a leap year".format(i))
      i+=1
      count+=1
    else :
        print(i,":-not a leap year")
        i+=1

else :
  print("not calculatble as TO<FOR")

print("\t\t\t\t\tTotal leap year:-",count2)

# %%
# Secret Castle game
print("\t\t\t\tA SECRET CASTLE\nWelcome to the game ")
print(":-You must enter the secret code to open the castle door\nCODE IS IN THREE DIGIT.")
print("Hint: The door only opens if the code is divisible by BOTH 3 and 5.\n")

life = 1

while life <= 3:
    code = int(input(f"Attempt {life}: Enter the secret code: "))

    if code <= 99 or code>=999 :
        print("Invalid input. Please enter a three digit no.")
        life += 1
        continue

    if code % 3 == 0 and code % 5 == 0:
        print("Access Granted! The door to the secret castle opens...")
        break
    elif code % 3 == 0:
        print("You are close! The code is divisible by 3.")
        life += 1
        continue
    elif code % 5 == 0:
        print("You are close! The code is divisible by 5.")
        life += 1
    else:
        print("Access Denied! This is not the correct code.")
        life += 1

if life > 3:
    print("\nOut of attempts. The castle remains locked.")

# %%
year=int(input("Enter the year:"))
if year%4==0:
    print(year,"is a leap year")
else :
  print(year,"not a leap year")

# %%
print("\t\t\tMENU")
print("JUICE's\nAPPLE:-30\tMANGO:-40\tBANANA:-50")
print("\t#Type none if no order")
order1=str(input("ORDER_1:-"))
if order1=="none":
  print("NO ORDER")
  price1=0
  ordquan1=0
  print("price:-0")
if alltot >=200:
  print("20% off on order of above 200")
  totaldis=total1*0.2+total2*0.2
  print("Total\t\t\t\t\t{}/-".format(alltot-totaldis))
else:
  print("No discount")z
  print("Total\t\t\t\t\t{}/-".format(alltot))
Double-click (or enter) to edit

# %%
q=int(input("from year:-"))
r=int(input("To year:-"))
x=i
count=0
if q<r:
  for i in range(q,r):
    if i%4==0:
      print("\t\t\t\t\t{}:-is a leap year".format(i))
      i+=1
      count+=1

# %%
#game in which hint and one time level can be used
print("Welcome to the numalpha puzzler game ")
start=str(input("START:-"))
level=1
Q1="which year is known as perfect square year?"
Q2="what is the capital of india?"
start=str(input("START:-"))
while start=='START':
  if level==1:
    print("Game is starting")
    print("q1:-",Q1)
    ans1=int(input("answer:-"))
    if ans1==2025:
      print("CORRECT\Moving to next")
    else:
      print("WRONG")
      print("GAME OVER")
      break
  elif level==2:
    print("q2:-",Q2)
    ans2=str(input("answer:-"))
    if ans2=="delhi":
      print("CORRECT\Moving to next")
    else:
      print("WRONG")
      print("GAME OVER")
      break

# %%
#snake water gun
print("SNAKE WATER GUN GAME \nMAKE FIRST 3 POINTS TO WIN FROM COMPUTER")
import random
c=['snake','water']
name=str(input("ENTER YOUR NAME:-"))

score=0
computer=0
n=0
while score<3 and computer<3:
  n+=1
  user=str(input(f"\nChoose:-SNAKE or WATER or GUN\n\n{n}:-{name}:-"))
  if user=='snake' or user=='water' or user=='gun':
        random_c = random.choice(c)
        x=random_c
        print("COMPUTER:-",x)
        if user==x:
            score+=1
            print(f"good +1\n\t\t\tcomputer={computer}\n\t\t\t{name}={score}")
            continue
        else :
                computer+=1
                print(f"hahaha\t\t\t\n\t\t\tcomputer={computer}\n\t\t\t{name}={score}")
                continue
  else:
                    print(f"wrong\nCheck your input {name}")
                    print(f"\t\t\t{name}={score}\n")
                    continue
else :
                        print(f"\t\t\tGAME COMPLETED")
                        if computer==3:
                            print(f"\nCOMPUTER WINS")
                        elif score==3:
                                print(f"{name} WINS")
                        else :
                                    print("DRAW")

# %%
name = ['anmol','akshita']
subject=['math','sciene']
mark=[2,3]
for ih in name:
 for item in subject:
  for ite in mark:
    print(ih,item,ite)

# %%
my_list = ['apple', 'banana', 'cherry']

for item in my_list:
    print(item)

# %%
x=("anml","anmol")
y=['anmol','anm']
z={'anml','anm'}
print(x,y,z)

# %%
people.add("narbhakshit")
for i in range(1,6)
  people.add(1)jh

 print()

# %%
name1=['anmol',48,80,66,70]
name2=['hardik',50,88,77,66]
name3=['khushi',4,55,66,773,22]
print(name1)
name1.remove(80)
name1.insert(1,60)
name1.append("khushi")
print(name1)

# %%
#12 july
#dictionary
student = {
    "name":"akshita",
    "age":"20",
    "branch":"computer science",
    "college":"anand internation college of enginnering"
}
print(student)
#access a value
print(student["name"])
student["college"] = "anand internation college of enginnering"
student["marks"]= 95
#del student["branch"]
if "age" in student:
  print("age is" , student["age"])
for key , value in student.items():
  print(key, ":" , value)

# %%
cart = {
    "apple":3,
    "banana":2,
    "orange":1
}
#add 1 more banana
cart["banana"] += 1
#print updated cart
for item , quantity in cart.items():
  print(f"{item}:{quantity}")

# %%
cart = {
    "apple":3,
    "banana":2,
    "orange":1
}
#add 1 more banana
cart["banana"] += 1
#print updated cart
for item , quantity in cart.items():
  print(f"{item}:{quantity}")

# %%
#python functions
def function():
  print("lakshita_hehahoha")


function() #function calling
